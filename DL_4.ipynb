# %%
from keras.datasets import boston_housing

# %%
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()

# %%
from sklearn.linear_model import LinearRegression
model_lr = LinearRegression()

# %%
model_lr.fit(train_data,train_targets)
# Out:
# LinearRegression()

# %%
y_predic = model_lr.predict(test_data)

# %%
import sklearn.metrics
import math

# %%
print("Before preprocessing",train_data)
# Out:
# Before preprocessing [[1.23247e+00 0.00000e+00 8.14000e+00 ... 2.10000e+01 3.96900e+02
#   1.87200e+01]
#  [2.17700e-02 8.25000e+01 2.03000e+00 ... 1.47000e+01 3.95380e+02
#   3.11000e+00]
#  [4.89822e+00 0.00000e+00 1.81000e+01 ... 2.02000e+01 3.75520e+02
#   3.26000e+00]
#  ...
#  [3.46600e-02 3.50000e+01 6.06000e+00 ... 1.69000e+01 3.62250e+02
#   7.83000e+00]
#  [2.14918e+00 0.00000e+00 1.95800e+01 ... 1.47000e+01 2.61950e+02
#   1.57900e+01]
#  [1.43900e-02 6.00000e+01 2.93000e+00 ... 1.56000e+01 3.76700e+02
#   4.38000e+00]]

# %%
mean = train_data.mean(axis = 0)
train_data = train_data-mean
std = train_data.std(axis = 0)
train_data = train_data/std
test_data = test_data-mean
test_data = test_data/std

# %%
print("After preprocessing",train_data)
# Out:
# After preprocessing [[-0.27224633 -0.48361547 -0.43576161 ...  1.14850044  0.44807713
#    0.8252202 ]
#  [-0.40342651  2.99178419 -1.33391162 ... -1.71818909  0.43190599
#   -1.32920239]
#  [ 0.1249402  -0.48361547  1.0283258  ...  0.78447637  0.22061726
#   -1.30850006]
#  ...
#  [-0.40202987  0.99079651 -0.7415148  ... -0.71712291  0.07943894
#   -0.67776904]
#  [-0.17292018 -0.48361547  1.24588095 ... -1.71818909 -0.98764362
#    0.42083466]
#  [-0.40422614  2.04394792 -1.20161456 ... -1.30866202  0.23317118
#   -1.15392266]]

# %%
mse = sklearn.metrics.mean_squared_error(test_targets, y_predic)
rmse = math.sqrt(mse)
print("MSE",mse)
print("RMSE",rmse)
# Out:
# MSE 23.195599256422994
# RMSE 4.816180982523704

# %% [markdown]
# ANN

# %%
from keras import models
from keras import layers
def build_model():
  model = models.Sequential()
  model.add(layers.Dense(64, activation='relu',input_shape=(train_data.shape[1],)))
  model.add(layers.Dense(64, activation='relu'))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
new_model = build_model()
new_model.fit(train_data,train_targets,epochs=15,batch_size=1)
# Out:
# Epoch 1/15
# 404/404 [==============================] - 2s 2ms/step - loss: 191.5148 - mae: 9.5069
# Epoch 2/15
# 404/404 [==============================] - 1s 1ms/step - loss: 24.8413 - mae: 3.1822
# Epoch 3/15
# 404/404 [==============================] - 0s 981us/step - loss: 18.1036 - mae: 2.7736
# Epoch 4/15
# 404/404 [==============================] - 0s 1ms/step - loss: 15.5026 - mae: 2.5935
# Epoch 5/15
# 404/404 [==============================] - 0s 1ms/step - loss: 14.7656 - mae: 2.4924
# Epoch 6/15
# 404/404 [==============================] - 0s 1ms/step - loss: 13.1626 - mae: 2.3790
# Epoch 7/15
# 404/404 [==============================] - 0s 980us/step - loss: 11.7746 - mae: 2.2882
# Epoch 8/15
# 404/404 [==============================] - 0s 1ms/step - loss: 11.4471 - mae: 2.2775
# Epoch 9/15
# 404/404 [==============================] - 0s 987us/step - loss: 10.5706 - mae: 2.2169
# Epoch 10/15
# ...

# %%
new_mse,new_rmse = new_model.evaluate(test_data,test_targets)
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 21.4438 - mae: 2.8817

# %%
new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 64)                896
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 1)                 65
#
# ...
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(new_mse)
print(new_rmse)
# Out:
# 21.443849563598633
# 2.881671667098999
