# %%
# Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
from tensorflow.random import set_seed

set_seed(455)
np.random.seed(455)

# %%
dataset = pd.read_csv( "/content/Mastercard_stock_history.csv", 
                      index_col="Date", parse_dates=["Date"]
).drop(["Dividends", "Stock Splits"], axis=1)
print(dataset.head())
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2006-05-25  3.748967  4.283869  3.739664  4.279217  395343000
# 2006-05-26  4.307126  4.348058  4.103398  4.179680  103044000
# 2006-05-30  4.183400  4.184330  3.986184  4.093164   49898000
# 2006-05-31  4.125723  4.219679  4.125723  4.180608   30002000
# 2006-06-01  4.179678  4.474572  4.176887  4.419686   62344000

# %%
print(dataset.describe())
# Out:
#               Open         High          Low        Close        Volume
# count  3872.000000  3872.000000  3872.000000  3872.000000  3.872000e+03
# mean    104.896814   105.956054   103.769349   104.882714  1.232250e+07
# std     106.245511   107.303589   105.050064   106.168693  1.759665e+07
# min       3.748967     4.102467     3.739664     4.083861  6.411000e+05
# 25%      22.347203    22.637997    22.034458    22.300391  3.529475e+06
# 50%      70.810079    71.375896    70.224002    70.856083  5.891750e+06
# 75%     147.688448   148.645373   146.822013   147.688438  1.319775e+07
# max     392.653890   400.521479   389.747812   394.685730  3.953430e+08

# %%
dataset.isna().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
tstart = 2016
tend = 2020

def train_test_plot(dataset, tstart, tend):
    dataset.loc[f"{tstart}":f"{tend}", "High"].plot(figsize=(16, 4), legend=True)
    dataset.loc[f"{tend+1}":, "High"].plot(figsize=(16, 4), legend=True)
    plt.legend([f"Train (Before {tend+1})", f"Test ({tend+1} and beyond)"])
    plt.title("MasterCard stock price")
    plt.show()

train_test_plot(dataset,tstart,tend)

# %%
def train_test_split(dataset, tstart, tend):
    train = dataset.loc[f"{tstart}":f"{tend}", "High"].values
    test = dataset.loc[f"{tend+1}":, "High"].values
    return train, test
training_set, test_set = train_test_split(dataset, tstart, tend)

# %%
training_set[0]
# Out:
# 92.14629263968936

# %%
sc = MinMaxScaler(feature_range=(0, 1))
training_set = training_set.reshape(-1, 1)
training_set_scaled = sc.fit_transform(training_set)

# %%
training_set_scaled[1]
# Out:
# array([0.04692574])

# %%
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence) - 1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)


n_steps = 10
features = 1
# split into samples
X_train, y_train = split_sequence(training_set_scaled, n_steps)

# %%
# Reshaping X_train for model
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],features)

# %% [markdown]
# LSTM Model

# %%
# The LSTM architecture
model_lstm = Sequential()
model_lstm.add(LSTM(units=125, activation="tanh", input_shape=(n_steps, features)))
model_lstm.add(Dense(units=1))
# Compiling the model
model_lstm.compile(optimizer="RMSprop", loss="mse")

model_lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 125)               63500
#
#  dense (Dense)               (None, 1)                 126
#
# =================================================================
# Total params: 63,626
# Trainable params: 63,626
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_lstm.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 3s 15ms/step - loss: 0.0104
# Epoch 2/50
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0015
# Epoch 3/50
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0016
# Epoch 4/50
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0014
# Epoch 5/50
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0015
# Epoch 6/50
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 7/50
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0013
# Epoch 8/50
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0010
# Epoch 9/50
# 40/40 [==============================] - 1s 15ms/step - loss: 9.5951e-04
# Epoch 49/50
# 40/40 [==============================] - 1s 15ms/step - loss: 4.0767e-04
# Epoch 50/50
# 40/40 [==============================] - 1s 26ms/step - loss: 4.3746e-04

# %%
dataset_total = dataset.loc[:,"High"]
inputs = dataset_total[len(dataset_total) - len(test_set) - n_steps :].values
inputs = inputs.reshape(-1, 1)
#scaling
inputs = sc.transform(inputs)

# Split into samples
X_test, y_test = split_sequence(inputs, n_steps)
# reshape
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], features)
#prediction
predicted_stock_price = model_lstm.predict(X_test)
#inverse transform the values
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 7/7 [==============================] - 0s 6ms/step

# %%
def plot_predictions(test, predicted):
    plt.plot(test, color="gray", label="Real")
    plt.plot(predicted, color="red", label="Predicted")
    plt.title("MasterCard Stock Price Prediction")
    plt.xlabel("Time")
    plt.ylabel("MasterCard Stock Price")
    plt.legend()
    plt.show()


def return_rmse(test, predicted):
    rmse = np.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {:.2f}.".format(rmse))

# %%
plot_predictions(test_set,predicted_stock_price)

# %%
return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean squared error is 8.56.

# %% [markdown]
# GRU Model

# %%
model_gru = Sequential()
model_gru.add(GRU(units=125, activation="tanh", input_shape=(n_steps, features)))
model_gru.add(Dense(units=1))
# Compiling the RNN
model_gru.compile(optimizer="RMSprop", loss="mse")

model_gru.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 125)               48000
#
#  dense_1 (Dense)             (None, 1)                 126
#
# =================================================================
# Total params: 48,126
# Trainable params: 48,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_gru.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 2s 12ms/step - loss: 0.0078
# Epoch 2/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 3/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0010
# Epoch 4/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0011
# Epoch 5/50
# 40/40 [==============================] - 0s 12ms/step - loss: 8.9202e-04
# Epoch 6/50
# 40/40 [==============================] - 1s 13ms/step - loss: 8.3143e-04
# Epoch 7/50
# 40/40 [==============================] - 0s 11ms/step - loss: 8.1585e-04
# Epoch 8/50
# 40/40 [==============================] - 0s 12ms/step - loss: 6.8333e-04
# Epoch 9/50
# 40/40 [==============================] - 0s 12ms/step - loss: 6.2801e-04
# Epoch 10/50
# 40/40 [==============================] - 0s 12ms/step - loss: 6.8915e-04
# Epoch 11/50
# 40/40 [==============================] - 0s 12ms/step - loss: 6.5836e-04
# Epoch 12/50
# 40/40 [==============================] - 0s 12ms/step - loss: 6.2243e-04
# Epoch 13/50
# 40/40 [==============================] - 0s 11ms/step - loss: 4.8263e-04
# Epoch 14/50
# 40/40 [==============================] - 0s 12ms/step - loss: 5.6306e-04
# Epoch 15/50
# 40/40 [==============================] - 0s 11ms/step - loss: 5.8227e-04
# Epoch 16/50
# 40/40 [==============================] - 0s 12ms/step - loss: 4.7745e-04
# Epoch 17/50
# 40/40 [==============================] - 1s 20ms/step - loss: 5.1371e-04
# Epoch 18/50
# 40/40 [==============================] - 1s 18ms/step - loss: 4.8308e-04
# Epoch 19/50
# 40/40 [==============================] - 1s 19ms/step - loss: 5.2150e-04
# Epoch 20/50
# 40/40 [==============================] - 1s 18ms/step - loss: 6.1026e-04
# Epoch 21/50
# 40/40 [==============================] - 0s 12ms/step - loss: 5.0113e-04
# Epoch 22/50
# 40/40 [==============================] - 0s 12ms/step - loss: 4.3193e-04
# Epoch 23/50
# 40/40 [==============================] - 0s 12ms/step - loss: 5.0010e-04
# Epoch 24/50
# 40/40 [==============================] - 0s 11ms/step - loss: 4.8708e-04
# Epoch 25/50
# 40/40 [==============================] - 1s 13ms/step - loss: 4.2911e-04
# Epoch 26/50
# 40/40 [==============================] - 0s 12ms/step - loss: 4.4287e-04
# Epoch 27/50
# 40/40 [==============================] - 0s 12ms/step - loss: 4.0106e-04
# Epoch 28/50
# 40/40 [==============================] - 0s 12ms/step - loss: 4.3396e-04
# Epoch 29/50
# 40/40 [==============================] - 1s 13ms/step - loss: 4.0260e-04
# Epoch 30/50
# 40/40 [==============================] - 0s 12ms/step - loss: 3.9447e-04
# Epoch 31/50
# 40/40 [==============================] - 0s 12ms/step - loss: 4.4060e-04
# Epoch 32/50
# 40/40 [==============================] - 0s 12ms/step - loss: 4.4332e-04
# Epoch 33/50
# 40/40 [==============================] - 0s 12ms/step - loss: 3.7091e-04
# Epoch 34/50
# 40/40 [==============================] - 0s 11ms/step - loss: 4.0554e-04
# Epoch 35/50
# 40/40 [==============================] - 0s 12ms/step - loss: 3.8290e-04
# Epoch 36/50
# 40/40 [==============================] - 0s 12ms/step - loss: 4.0551e-04
# Epoch 37/50
# 40/40 [==============================] - 0s 12ms/step - loss: 3.6597e-04
# Epoch 38/50
# 40/40 [==============================] - 0s 12ms/step - loss: 4.4617e-04
# Epoch 39/50
# 40/40 [==============================] - 0s 12ms/step - loss: 4.2689e-04
# Epoch 40/50
# 40/40 [==============================] - 1s 13ms/step - loss: 3.6408e-04
# Epoch 41/50
# 40/40 [==============================] - 1s 16ms/step - loss: 3.7007e-04
# Epoch 42/50
# 40/40 [==============================] - 1s 19ms/step - loss: 4.5586e-04
# Epoch 43/50
# 40/40 [==============================] - 1s 20ms/step - loss: 3.4291e-04
# Epoch 44/50
# 40/40 [==============================] - 1s 19ms/step - loss: 3.4914e-04
# Epoch 45/50
# 40/40 [==============================] - 1s 14ms/step - loss: 3.7698e-04
# Epoch 46/50
# 40/40 [==============================] - 0s 12ms/step - loss: 3.9831e-04
# Epoch 47/50
# 40/40 [==============================] - 0s 12ms/step - loss: 3.5715e-04
# Epoch 48/50
# 40/40 [==============================] - 1s 13ms/step - loss: 3.5358e-04
# Epoch 49/50
# 40/40 [==============================] - 0s 12ms/step - loss: 3.3120e-04
# Epoch 50/50
# 40/40 [==============================] - 1s 12ms/step - loss: 3.5474e-04

# %%
GRU_predicted_stock_price = model_gru.predict(X_test)
GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)
plot_predictions(test_set, GRU_predicted_stock_price)
# Out:
# 7/7 [==============================] - 1s 5ms/step

# %%
return_rmse(test_set,GRU_predicted_stock_price)
# Out:
# The root mean squared error is 5.78.

# %% [markdown]
# #EXTRA PART

# %%
dataset_total = dataset.loc[:,"Close"]
inputs = dataset_total[len(dataset_total) - len(test_set) - n_steps :].values
inputs = inputs.reshape(-1, 1)
#scaling
inputs = sc.transform(inputs)

# Split into samples
X_test, y_test = split_sequence(inputs, n_steps)
# reshape
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], features)
#prediction
predicted_stock_price = model_lstm.predict(X_test)
#inverse transform the values
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 7/7 [==============================] - 0s 6ms/step

# %%
def plot_predictions(test, predicted):
    plt.plot(test, color="gray", label="Real")
    plt.plot(predicted, color="red", label="Predicted")
    plt.title("MasterCard Stock Close Price Prediction")
    plt.xlabel("Time")
    plt.ylabel("MasterCard Stock Price")
    plt.legend()
    plt.show()


def return_rmse(test, predicted):
    rmse = np.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {:.2f}.".format(rmse))

# %%
plot_predictions(test_set,predicted_stock_price)
